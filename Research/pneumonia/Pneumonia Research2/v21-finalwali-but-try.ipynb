# %%
# Cell 1: Import libraries and set seeds for reproducibility.
import os
import math
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import pydicom
import cv2

from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight

# Set seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("✅ Libraries imported and seeds set!")
# Out:
# ✅ Libraries imported and seeds set!

# %%
# Cell 2: Load dataset metadata and split data into training and validation sets.
dataset_path = "/kaggle/input/rsna-pneumonia-detection-challenge"
train_labels_csv = os.path.join(dataset_path, "stage_2_train_labels.csv")
class_info_csv = os.path.join(dataset_path, "stage_2_detailed_class_info.csv")

# Read CSV files
labels_df = pd.read_csv(train_labels_csv)
class_info_df = pd.read_csv(class_info_csv)

# Merge on 'patientId' and simplify labels (0: Normal, 1: Pneumonia)
merged_df = pd.merge(labels_df, class_info_df, on="patientId")
labels_simple = merged_df[['patientId', 'Target']].drop_duplicates().reset_index(drop=True)
labels_simple['Target'] = labels_simple['Target'].map({0: 'Normal', 1: 'Pneumonia'})
labels_simple['patientId'] = labels_simple['patientId'].astype(str) + ".dcm"

# Split data (80% train, 20% validation), stratified by target.
train_df, val_df = train_test_split(labels_simple, test_size=0.2, random_state=SEED, stratify=labels_simple['Target'])
print("Train samples:", len(train_df))
print("Validation samples:", len(val_df))
# Out:
# Train samples: 21347
# Validation samples: 5337

# %%
# Cell 3: Define a function to load and preprocess DICOM images.
def load_preprocess_dicom(dicom_path, img_size=(240,240)):
    dicom_data = pydicom.dcmread(dicom_path)
    img_array = dicom_data.pixel_array.astype(np.float32)
    # Normalize pixel values to [0,1]
    img_norm = (img_array - np.min(img_array)) / (np.max(img_array) - np.min(img_array) + 1e-10)
    # Resize image
    img_resized = cv2.resize(img_norm, img_size)
    # Convert grayscale to 3-channel RGB
    img_rgb = np.stack([img_resized]*3, axis=-1)
    return img_rgb

# Test the function on a sample image
sample_image_path = os.path.join(dataset_path, "stage_2_train_images", train_df.iloc[0]['patientId'])
sample_img = load_preprocess_dicom(sample_image_path)
print("✅ Sample image shape (should be 240x240x3):", sample_img.shape)
# Out:
# ✅ Sample image shape (should be 240x240x3): (240, 240, 3)

# %%
# Cell 4: Create data generators for training and validation.
def data_generator(df, batch_size=64, img_size=(240,240), infinite=True):
    def gen():
        if infinite:
            while True:
                shuffled_df = df.sample(frac=1).reset_index(drop=True)
                for _, row in shuffled_df.iterrows():
                    patient_id = row['patientId']
                    label = 1 if row['Target'] == 'Pneumonia' else 0
                    dicom_path = os.path.join(dataset_path, "stage_2_train_images", patient_id)
                    img = load_preprocess_dicom(dicom_path, img_size)
                    yield img, label
        else:
            for _, row in df.iterrows():
                patient_id = row['patientId']
                label = 1 if row['Target'] == 'Pneumonia' else 0
                dicom_path = os.path.join(dataset_path, "stage_2_train_images", patient_id)
                img = load_preprocess_dicom(dicom_path, img_size)
                yield img, label

    ds = tf.data.Dataset.from_generator(
        gen,
        output_types=(tf.float32, tf.int32),
        output_shapes=((img_size[0], img_size[1], 3), ())
    )
    ds = ds.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

BATCH_SIZE = 64
train_ds = data_generator(train_df, batch_size=BATCH_SIZE, img_size=(240,240), infinite=True)
val_ds = data_generator(val_df, batch_size=BATCH_SIZE, img_size=(240,240), infinite=False)
print("✅ Data generators created with batch size:", BATCH_SIZE)
# Out:
# ✅ Data generators created with batch size: 64

# %%
# Cell 5: Compute class weights to mitigate class imbalance.
y_train = train_df['Target'].apply(lambda x: 1 if x == 'Pneumonia' else 0)
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = {i: w for i, w in enumerate(weights)}
print("✅ Class weights computed:", class_weights)
# Out:
# ✅ Class weights computed: {0: 0.6454314567333858, 1: 2.219022869022869}

# %%
# Cell 6: Install Keras Tuner (if not already installed)
# !pip install -q keras-tuner
import keras_tuner as kt

# %%
# Cell 7: Define the model building function for hyperparameter tuning.
def build_model(hp):
    from tensorflow.keras.applications import DenseNet201
    from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
    from tensorflow.keras.models import Model

    # Load DenseNet201 with ImageNet weights (without the top classifier)
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(240,240,3))
    
    # Hyperparameter to decide whether to unfreeze the base or not
    unfreeze = hp.Boolean('unfreeze', default=True)
    if unfreeze:
        base_model.trainable = True
    else:
        base_model.trainable = False

    inputs = Input(shape=(240,240,3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    # Hyperparameter: number of units in the Dense layer
    dense_units = hp.Int('dense_units', min_value=64, max_value=256, step=32, default=128)
    x = Dense(dense_units, activation='relu')(x)
    # Hyperparameter: dropout rate
    dropout_rate = hp.Float('dropout', 0.2, 0.5, step=0.1, default=0.5)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    # Hyperparameter: learning rate (use a smaller rate if unfreezing)
    lr = hp.Float('lr', min_value=1e-5, max_value=1e-3, sampling='LOG', default=1e-4)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Instantiate the tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='my_dir',
    project_name='DenseNet201_tuning'
)

tuner.search_space_summary()
# Out:
# Reloading Tuner from my_dir/DenseNet201_tuning/tuner0.json
# Search space summary
# Default search space size: 4
# unfreeze (Boolean)
# {'default': True, 'conditions': []}
# dense_units (Int)
# {'default': 128, 'conditions': [], 'min_value': 64, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout (Float)
# {'default': 0.5, 'conditions': [], 'min_value': 0.2, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 1e-05, 'max_value': 0.001, 'step': None, 'sampling': 'log'}

# %%
# Cell 8: Run the hyperparameter search on the training dataset.
steps_per_epoch = math.ceil(len(train_df) / BATCH_SIZE)
EPOCHS = 10

tuner.search(
    train_ds,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    class_weight=class_weights
)

# Get the best hyperparameters.
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
print("✅ Best hyperparameters found:")
print(best_hp.values)
# Out:
# Trial 10 Complete [00h 59m 58s]
# val_accuracy: 0.7972643971443176
#
# Best val_accuracy So Far: 0.8309912085533142
# Total elapsed time: 1d 05h 38m 05s
# ✅ Best hyperparameters found:
# {'unfreeze': True, 'dense_units': 64, 'dropout': 0.30000000000000004, 'lr': 0.00010733251249694184}

# %%
import json

# Step 1: Get the best hyperparameters
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
print("✅ Best hyperparameters found:")
print(best_hp.values)

# Step 2: Save to JSON (already saves in /kaggle/working/)
with open("best_hyperparameters.json", "w") as f:
    json.dump(best_hp.values, f, indent=4)

print("✅ Saved as best_hyperparameters.json — ready to download from the Output tab")
# Out:
# ✅ Best hyperparameters found:
# {'unfreeze': True, 'dense_units': 64, 'dropout': 0.30000000000000004, 'lr': 0.00010733251249694184}
# ✅ Saved as best_hyperparameters.json — ready to download from the Output tab

# %%
# Save the best model in HDF5 (.h5) format
best_model.save('best_pneumonia_model.h5')  # Works fine

# Save in SavedModel format (for TF Serving, TFLite, etc.)
best_model.export('best_pneumonia_model')  # <-- Use `.export()` instead of `.save()`

# Zip the SavedModel directory for download
import shutil
shutil.make_archive('best_pneumonia_model', 'zip', 'best_pneumonia_model')
# Out:
# Saved artifact at 'best_pneumonia_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 240, 240, 3), dtype=tf.float32, name='keras_tensor_1420')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   138264631658976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264631658272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264631659680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264631662848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285831840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285828672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285833600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285826912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285832368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285837472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858398304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285839056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138264285838000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858397424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858404992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858406752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858408512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858405872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858407280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858412208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858513696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858514048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858513168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858520384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858522144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858523904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858521264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858522672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858527600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858563552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858561440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858561264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858563024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858570240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858572000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858573760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858571120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858572528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858573936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858695328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858696384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858693216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858694800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858702016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858703776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858705536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858702896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858704304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263858705712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913320288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913321344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913319760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913326976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913328736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913330496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913327856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913329264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913330672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913415424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913420352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913416656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913418768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913425984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913427744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913429504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913426864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913428272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913429680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913486240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913488000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913485360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913486768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913493632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913490816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913495744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913492048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913494160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913495920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913585248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913587008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913584368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913585776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913592640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913589824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913591584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913591056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913593168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913649728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913651488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913653248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913650608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913652016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913658880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913655712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913658000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913659232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913658176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913748736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913750496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913752256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913749616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913751024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913755952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913754720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913758240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913755072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913840880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913847744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913849504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913851264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913848624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913850032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913854960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913923680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913854080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913856720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913922800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913930368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913932128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913933888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913931248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913932656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913937584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914039072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914039248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914039424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914038544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914045760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914047520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914049280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914046640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914048048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914052976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914105312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914103200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914103024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914104784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914112000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914113760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914115520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914112880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914114288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914115696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914187936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914188992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914185824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914187408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914194624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914196384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914198144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914195504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914196912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914198320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914286944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914288000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914284304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914286416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914293632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914295392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914297152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914294512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914295920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263914297328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912301312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912306240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912302544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912304656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912311872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912313632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912315392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912312752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912314160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912315568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912400320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912405248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912401552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912403664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912410880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912412640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912414400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912411760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912413168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912414576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912466560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912471488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912467792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912469904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912477120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912478880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912478000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912479408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912568384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912570144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912571904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912569264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912570672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912577536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912574368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912576656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912577888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912576832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912651008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912652768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912654528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912651888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912653296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912658224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912656992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912660512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912657344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912760064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912766400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912768160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912769920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912767280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912768688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912773616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912842336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912772736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912775376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912841456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912849024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912850784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912852544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912849904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912851312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912856240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912908576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912908752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912908928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912908048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912915264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912917024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912918784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912916144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912917552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912922480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913007584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913005472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913005296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913007056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913014272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913016032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913017792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913015152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913016560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913017968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913106592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913107648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913104480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913106064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913113280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913115040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913116800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913114160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913115568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913116976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913189216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913190272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913186576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913188688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913195904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913197664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913199424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913196784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913198192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913199600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913267968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913272896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913269200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913271312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913278528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913280288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913282048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913279408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913280816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263913282224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911286208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911291136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911289552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911296768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911298528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911300288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911297648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911299056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911300464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911385216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911390144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911386448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911388560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911395776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911397536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911396304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911396656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911398064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911470656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911467840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911472768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911469072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911471184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911478400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911475232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911478928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911479280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911480688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911586048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911583232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911588160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911584464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911586576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911593792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911590624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911595024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911594672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911645424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911652288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911649472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911654400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911650704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911652816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911660032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911761520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911660912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911760816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911767680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911764864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911769792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911766096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911768208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911773488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911827760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911825648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911826352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911827056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911833920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911831104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911836032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911832336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911834448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911839728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911877616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911875856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911876912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911883776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911880960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911885888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911889584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911993008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911989312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911990896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911992304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911999168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911996352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912001280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911997584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911999696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912004976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912092016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912092544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912089904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912091312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912098176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912095360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912100288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912096592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912098704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912100464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912174640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912175168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912172528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912173936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912180800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912177984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912182912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912179216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912181328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263912183088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910176496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910177024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910174384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910175792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910182656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910179840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910184768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910181072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910183184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910184944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910323424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910325184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910322544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910323952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910330816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910328000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910332928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910329232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910331344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910333104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910389664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910391424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910388784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910390192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910397056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910394240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910399168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910395472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910397584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910399344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910455904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910457664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910455024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910456432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910463296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910460480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910462240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910463824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910553152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910554912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910556672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910554032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910555440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910562304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910559136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910562656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910561600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910635776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910637536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910639296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910636656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910638064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910642992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910641760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910645280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910642112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910744304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910751168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910752928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910754688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910752048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910753456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910758384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910827104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910757504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910760144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910826224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910833792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910835552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910837312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910834672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910836080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910841008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910958880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910959056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910959232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910958352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910965568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910967328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910969088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910966448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910967856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910972784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911025120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911023008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911022832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911024592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911031808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911033568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911035328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911032688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911034096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911035504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911107744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911108800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911105632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911107216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911114432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911116192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911117952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911115312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911116720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263911118128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909142368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909143424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909141840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909149056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909150816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909152576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909149936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909151344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909152752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909204736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909209664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909205968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909208080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909215296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909217056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909218816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909216176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909217584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909218992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909320128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909325056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909321360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909323472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909330688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909332448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909334208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909331568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909332976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909334384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909402752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909407680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909403984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909406096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909413312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909415072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909413840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909414192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909415600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909488192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909485376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909490304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909488720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909495936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909492768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909496464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909496816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909498224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909570816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909568000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909572928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909569232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909571344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909578560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909575392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909579792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909579440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909679344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909686208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909683392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909688320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909684624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909686736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909693952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909746288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909694832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909693776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909745584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909752448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909749632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909754560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909752976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909758256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909845296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909843184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909843888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909844592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909851456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909848640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909853568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909849872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909851984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909857264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909944304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909941840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909942544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909943600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909950464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909947648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909952576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909948880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263909956272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910026928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910023232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910024816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910026224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910033088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910030272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910035200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910038896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910125936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910126464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910123824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910125232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910132096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910129280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910134208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910130512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910132624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263910134384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908144176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908144704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908142064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908143472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908150336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908147520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908152448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908148752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908150864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908152624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908226800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908227328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908224688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908226096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908232960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908230144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908235072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908231376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908233488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908235248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908340960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908342720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908340080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908341488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908348352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908345536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908350464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908346768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908348880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908350640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908407200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908408960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908406320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908407728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908414592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908411776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908416704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908413008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908415120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908416880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908506208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908507968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908505328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908506736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908513600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908510784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908512544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908512016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908514128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908636224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908637984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908639744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908637104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908638512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908645376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908642208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908644496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908645728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908644672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908718848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908720608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908722368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908719728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908721136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908726064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908724832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908728352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908725184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908794608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908801472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908803232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908804992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908802352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908803760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908808688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263908862960: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   138263907740032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907737392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907738800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907743728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907812448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907742848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907745488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907811568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907819136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907820896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907822656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907820016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907821424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907826352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907895072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907895424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907894544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907901760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907903520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907905280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907902640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907904048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907908976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907977696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907975584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907975408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907977168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907984384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907986144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907987904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907985264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907986672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263907988080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906012320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906013376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906010208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906019008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906020768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906022528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906019888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906021296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906022704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906094944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906096000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906092304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906094416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906101632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906103392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906105152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906102512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906103920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906105328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906206464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906211392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906207696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906209808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906217024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906218784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906220544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906217904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906219312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906220720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906305472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906310400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906306704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906308816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906316032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906317792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906319552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906316912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906318320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906319728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906388096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906393024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906389328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906391440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906398656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906400416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906399184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906399536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906400944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906489920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906487104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906492032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906488336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906490448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906497664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906494496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906498544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906499952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906572544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906569728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906574656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906570960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906573072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906580288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906577120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906581520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906581168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906664688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906671552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906668736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906673664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906669968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906672080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906679296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906731632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906680176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906679120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906730928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906737792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906734976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906739904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906736208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906738320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906743600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906830640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906828880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906828704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906829936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906836800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906833984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906838912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906835216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906837328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906842608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906929648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906927888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906927712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906928944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906935808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906932992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906937920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906934224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906936336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906941616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906979504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906975808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906977392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906978800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906985664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906982848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906987776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263906991472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896641904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896642432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896639792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896641200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896648064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896645248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896650176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896646480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896648592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896650352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896740912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896741440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896738800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896740208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896747072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896744256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896749184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896745488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896747600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896749360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896823536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896824064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896821424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896822832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896829696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896826880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896831808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896828112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896830224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896831984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896921312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896923072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896920432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896921840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896928704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896925888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896930816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896927120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896929232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263896930992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897020320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897022080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897019440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897020848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897027712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897024896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897029824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897026128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897030000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897102944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897104704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897102064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897103472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897110336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897107520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897109280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897108752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897110864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897183808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897185568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897187328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897184688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897186096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897192960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897189792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897193312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897192256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897299200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897300960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897302720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897300080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897301488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263897302016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263895933168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263895938096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138263895938976: TensorSpec(shape=(), dtype=tf.resource, name=None)
# '/kaggle/working/best_pneumonia_model.zip'

# %%
# Cell 9: Build the model with the best hyperparameters from the tuner.
best_model = tuner.hypermodel.build(best_hp)
best_model.summary()

# Train this model with the frozen base.
history = best_model.fit(
    train_ds,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    callbacks=[EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True, verbose=1),
               ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)],
    class_weight=class_weights
)
# Save the best model after training
best_model.save('best_pneumonia_model.h5')  # Saves in HDF5 format
# Save the best model in SavedModel format
best_model.save('best_pneumonia_model')
import shutil
shutil.make_archive('best_pneumonia_model', 'zip', 'best_pneumonia_model')
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 240, 240, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ densenet201 (Functional)             │ (None, 7, 7, 1920)          │      18,321,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1920)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │         122,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,444,993 (70.36 MB)
#  Trainable params: 18,215,937 (69.49 MB)
#  Non-trainable params: 229,056 (894.75 KB)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3fea35b8fede> in <cell line: 6>()
#       9     steps_per_epoch=steps_per_epoch,
#      10     validation_data=val_ds,
# ---> 11     callbacks=[EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True, verbose=1),
#      12                ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)],
#      13     class_weight=class_weights
#
# NameError: name 'EarlyStopping' is not defined

# %%
# Cell 10: Clone the frozen-base model for later evaluation.
model_frozen = tf.keras.models.clone_model(best_model)
model_frozen.build((None, 240,240,3))
model_frozen.set_weights(best_model.get_weights())
print("✅ Frozen-base model cloned.")

# %%
# Cell 11: Unfreeze the base layers for fine-tuning.
# Here we unfreeze all layers; alternatively, you can partially unfreeze.
from tensorflow.keras.optimizers import Adam

base_model = best_model.layers[0]  # Assuming the base model is the first layer in the Sequential model.
base_model.trainable = True

# Recompile with a lower learning rate for fine-tuning.
best_model.compile(optimizer=Adam(learning_rate=1e-5),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])
print("✅ Base model layers unfrozen for fine-tuning.")

# %%
# Cell 12: Fine-tune the model with unfrozen base layers.
FINE_TUNE_EPOCHS = 10

fine_tune_history = best_model.fit(
    train_ds,
    epochs=FINE_TUNE_EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    callbacks=[EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True, verbose=1),
               ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)],
    class_weight=class_weights
)

# %%
# Cell 13: Evaluate the frozen-base and fine-tuned models using evaluation metrics and plot ROC curves.
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc

def evaluate_model(model, dataset, stage_name=""):
    y_true = []
    y_pred = []
    y_scores = []  # Raw probabilities
    
    for images, labels in dataset:
        preds = model.predict(images)
        y_true.extend(labels.numpy())
        y_pred.extend((preds > 0.5).astype("int32").flatten())
        y_scores.extend(preds.flatten())
    
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    fpr, tpr, _ = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"=== {stage_name} Model ===")
    print("Accuracy: {:.2f}%".format(acc * 100))
    print("Precision: {:.2f}".format(prec))
    print("Recall: {:.2f}".format(rec))
    print("F1-Score: {:.2f}".format(f1))
    print("Confusion Matrix:\n", cm)
    print("AUC: {:.2f}".format(roc_auc))
    print()
    
    plt.figure(figsize=(8,6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC (AUC = {:.2f})'.format(roc_auc))
    plt.plot([0,1], [0,1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{stage_name} ROC Curve')
    plt.legend(loc="lower right")
    plt.show()

# Evaluate the frozen-base model
evaluate_model(model_frozen, val_ds, stage_name="Frozen Base")

# Evaluate the fine-tuned model (current best_model)
evaluate_model(best_model, val_ds, stage_name="Fine-Tuned")

# %%
# Cell 14: Plot combined learning curves for accuracy and loss.
plt.figure(figsize=(14,5))

# Accuracy Plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Frozen Base - Train Acc')
plt.plot(history.history['val_accuracy'], label='Frozen Base - Val Acc')
plt.plot(fine_tune_history.history['accuracy'], label='Fine-Tuned - Train Acc')
plt.plot(fine_tune_history.history['val_accuracy'], label='Fine-Tuned - Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss Plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Frozen Base - Train Loss')
plt.plot(history.history['val_loss'], label='Frozen Base - Val Loss')
plt.plot(fine_tune_history.history['loss'], label='Fine-Tuned - Train Loss')
plt.plot(fine_tune_history.history['val_loss'], label='Fine-Tuned - Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()
